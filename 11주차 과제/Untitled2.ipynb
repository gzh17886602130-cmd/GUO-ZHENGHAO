# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# MNIST 数据集加载
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# 创建子图
fig = plt.figure(figsize=(12, 3))
ax1 = fig.add_subplot(1, 4, 1)
ax2 = fig.add_subplot(1, 4, 2)
ax3 = fig.add_subplot(1, 4, 3)
ax4 = fig.add_subplot(1, 4, 4)

# 在子图中显示图像
ax1.imshow(train_images[1000], cmap='gray')
ax1.set_title(f'Label: {train_labels[1000]}')
ax1.axis('off')

ax2.imshow(train_images[2000], cmap='gray')
ax2.set_title(f'Label: {train_labels[2000]}')
ax2.axis('off')

ax3.imshow(train_images[3000], cmap='gray')
ax3.set_title(f'Label: {train_labels[3000]}')
ax3.axis('off')

ax4.imshow(train_images[4000], cmap='gray')
ax4.set_title(f'Label: {train_labels[4000]}')
ax4.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
